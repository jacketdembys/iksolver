# %%
# !pip install -U kaleido
# !pip install plotly==5.18.0

# %%
import plotly
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../ikresults/results_input_variations.csv")
data
# Out:
#                   device_name  data_size  joints_scale  \
# 0  NVIDIA GeForce RTX 2080 Ti    1000000            10
# 1     NVIDIA GeForce RTX 3090    1000000            10
# 2     NVIDIA GeForce RTX 3090    1000000            10
# 3     NVIDIA GeForce RTX 3090    1000000            10
# 4     NVIDIA GeForce RTX 3090    1000000            10
# 5     NVIDIA GeForce RTX 3090    1000000            10
#
#                                         architecture   network  layers  \
# 0  MLP [6, 1024, 1024, 1024, 1024, 1024, 1024, 10...       MLP      10
# 1  MLP [19, 1024, 1024, 1024, 1024, 1024, 1024, 1...       MLP      10
# 2                             ResMLP [6, 1024, 5, 7]    ResMLP       5
# 3                            ResMLP [19, 1024, 5, 7]    ResMLP       5
# 4                           DenseMLP [6, 1024, 5, 7]  DenseMLP       5
# 5                          DenseMLP [19, 1024, 5, 7]  DenseMLP       5
#
#    neurons optimizer loss  completed_epochs  ...  pi_percent_5(deg)  \
# ...

# %%
data_plot_pos = []
data_plot_pos_min = []
data_plot_pos_max = []
data_plot_ori = []

layers_pose = pd.DataFrame(data, columns = ['average_position(mm)', 'average_orientation(deg)'])
data_plot_pose = layers_pos.to_numpy()
